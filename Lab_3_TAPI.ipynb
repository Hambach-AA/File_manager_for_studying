# %% [markdown]
# <a href="https://colab.research.google.com/github/Hambach-AA/File_manager_for_studying/blob/master/Lab_3_TAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

# %%
df = pd.read_csv("grades.csv")
df.head()
df.shape
# Out:
# (72, 9)

# %%
# проверка на наличие пропущенных значений
df.isnull().sum()
# Out:
# PUPIL_SEX        0
# PUPIL_CLASS      0
# TEACHER_RIGHT    0
# TEACHER_CHK      0
# TEACHER_QUEST    0
# TEACHER_CORR     0
# PUPIL_CORR       0
# PUPIL_STRIP      0
# GRADE            0
# dtype: int64

# %%
# статистика фреймов данных
df.describe()
# Out:
#        TEACHER_RIGHT  TEACHER_CHK  TEACHER_QUEST  TEACHER_CORR  PUPIL_CORR  \
# count      72.000000    72.000000      72.000000     72.000000   72.000000
# mean       66.458333     0.305556       0.500000      1.555556    1.597222
# std        30.541100     0.704890       0.919277      1.582376    2.243361
# min         0.000000     0.000000       0.000000      0.000000    0.000000
# 25%        47.500000     0.000000       0.000000      0.000000    0.000000
# 50%        70.000000     0.000000       0.000000      1.000000    1.000000
# 75%        95.000000     0.000000       1.000000      2.000000    2.000000
# max       100.000000     4.000000       4.000000      6.000000   10.000000
#
#        PUPIL_STRIP
# count    72.000000
# mean      2.861111
# std       3.031783
# min       0.000000
# 25%       0.750000
# 50%       2.000000
# 75%       4.250000
# max      12.000000

# %%
# Изменение обозначения
df['PUPIL_SEX'] = df['PUPIL_SEX'].replace(['M','F'],['0','1'])
df['PUPIL_CLASS'] = df['PUPIL_CLASS'].replace(['8A','8B'],['0','1'])


# определение входной и целевой переменных
X = df[["PUPIL_SEX","PUPIL_CLASS","TEACHER_RIGHT", "TEACHER_CHK", "TEACHER_QUEST", "TEACHER_CORR", "PUPIL_CORR", "PUPIL_STRIP"]]
Y = df.GRADE

f1 = []
accur = []
precis = []
rec = []

# %%
# разделение тестовых и обучающих данных
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4, train_size = 0.6)


# определение алгоритма классификации
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)

# генерация прогнозов
y_pred = dt_clf.predict(X_test)
feature_names = ["PUPIL_SEX","PUPIL_CLASS","TEACHER_RIGHT", "TEACHER_CHK", "TEACHER_QUEST", "TEACHER_CORR", "PUPIL_CORR", "PUPIL_STRIP"]

fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=10,
                feature_names=feature_names,
                filled=True)
y_test.shape




f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.43650793650793646
# Аккуратность :  0.4482758620689655
# Точность :  0.4908163265306123
# Полнота :  0.4086734693877551

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, train_size = 0.7)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=10,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.48587127158555726
# Аккуратность :  0.5454545454545454
# Точность :  0.5214285714285715
# Полнота :  0.4920634920634921

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, train_size = 0.8)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=10,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.38730158730158726
# Аккуратность :  0.6
# Точность :  0.375
# Полнота :  0.4444444444444444

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, train_size = 0.9)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=10,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.2261904761904762
# Аккуратность :  0.5
# Точность :  0.2222222222222222
# Полнота :  0.2916666666666667

# %%
names = ["60/40","70/30","80/20","90/10"]
plt.bar(names, f1)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("F-мера")
plt.show()
plt.bar(names, accur)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("Аккуратность")
plt.show()
plt.bar(names, precis)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("Точность")
plt.show()
plt.bar(names, rec)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("Полнота")
plt.show()

# %%
df = pd.read_csv("heart_disease.csv")
df.head()
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df['Sex'] = df['Sex'].replace(['M','F'],['0','1'])
df['ExerciseAngina'] = df['ExerciseAngina'].replace(['N','Y'],['0','1'])
X = df[["Age","Sex","RestingBP", "Cholesterol", "FastingBS", "MaxHR", "ExerciseAngina"]]
Y = df.HeartDisease
feature_names = ["Age","Sex","RestingBP", "Cholesterol", "FastingBS", "MaxHR", "ExerciseAngina"]
f1 = []
accur = []
precis = []
rec = []

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.4, train_size = 0.6)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=3,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.681013868962219
# Аккуратность :  0.6847826086956522
# Точность :  0.6804436383098926
# Полнота :  0.682615629984051

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, train_size = 0.7)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=3,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.6971723928245668
# Аккуратность :  0.6992753623188406
# Точность :  0.6984696317551411
# Полнота :  0.696786090621707

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, train_size = 0.8)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=3,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.6758919241677861
# Аккуратность :  0.6793478260869565
# Точность :  0.6761363636363636
# Полнота :  0.6806044422866853

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, train_size = 0.9)
dt_clf = tree.DecisionTreeClassifier(criterion = "gini")
dt_clf = dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(dt_clf, 
                max_depth=3,
               feature_names=feature_names,
               filled=True)
y_test.shape
f1.append(float(f1_score(y_test, y_pred,average='macro')))
accur.append(float(accuracy_score(y_test, y_pred)))
precis.append(float(precision_score(y_test, y_pred, average='macro')))
rec.append(float(recall_score(y_test, y_pred, average='macro')))
print("F-мера : " , f1_score(y_test, y_pred,average='macro'))
print("Аккуратность : " , accuracy_score(y_test, y_pred))
print("Точность : " , precision_score(y_test, y_pred, average='macro'))
print("Полнота : " , recall_score(y_test, y_pred,average='macro'))
# Out:
# F-мера :  0.706487061325771
# Аккуратность :  0.7065217391304348
# Точность :  0.708827717133365
# Полнота :  0.7083333333333333

# %%
plt.bar(names, f1)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("F-мера")
plt.show()
plt.bar(names, accur)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("Аккуратность")
plt.show()
plt.bar(names, precis)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("Точность")
plt.show()
plt.bar(names, rec)
plt.xlabel("Соотношение мощностей обучающей и тестовой выборок")
plt.ylabel("Полнота")
plt.show()
